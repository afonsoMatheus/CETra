# %%
import util 
import transitions as trans
import evolution_clustering as ec

# %%
evo_clusters, centers = ec.init_clustering()

# %%
evo_clusters, centers = ec.new_clustering(evo_clusters, centers, ["int_size_reduc","int_size_grow"])

# %%
evo_clusters, centers = ec.new_clustering(evo_clusters, centers, ["int_local","int_den_dif"])

# %%
util.plot_view_all(evo_clusters, centers)
