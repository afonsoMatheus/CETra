# %%
import util 
import transitions as trans
import evolution_clustering as ec

# %%
evo_clusters, centers = ec.init_clustering()

# %%
evo_clusters, centers = ec.new_clustering(evo_clusters, centers, ["int_size_reduc","ext_div"])
# Out:
# {0: 4, 1: 5, 2: 6}

# %%
evo_clusters, centers = ec.new_clustering(evo_clusters, centers, ["ext_union", "int_den_dif"])

# %%
util.plot_view_all(evo_clusters, centers)
